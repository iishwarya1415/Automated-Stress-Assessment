# %% [markdown]
# # GRADIENT BOOSTING ALGORITHM

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('stress level.csv')
df.head()
# Out:
#    snoring rate  respiration rate  body temperature  limb movement  \
# 0           NaN               0.0              78.0            NaN
# 1          16.0               NaN              70.0           18.0
# 2         115.0              77.0             101.0            5.0
# 3         140.0              43.0              88.0            0.0
# 4          69.0               NaN              69.0            NaN
#
#    blood oxygen   eye movement  sleeping hours  heart rate  stress level
# 0             56          24.0            21.0        64.0             3
# 1             92          22.0            13.0        30.0             4
# 2             88          23.0            24.0        68.0             2
# 3             66          23.0            11.0       165.0             0
# 4             79          21.0            18.0       189.0             2

# %%
df=df.dropna()

# %%
df.columns
# Out:
# Index(['snoring rate', 'respiration rate', 'body temperature', 'limb movement',
#        'blood oxygen ', 'eye movement', 'sleeping hours', 'heart rate',
#        'stress level'],
#       dtype='object')

# %%
df.head()
# Out:
#    snoring rate  respiration rate  body temperature  limb movement  \
# 2         115.0              77.0             101.0            5.0
# 3         140.0              43.0              88.0            0.0
# 5         107.0              51.0              88.0           11.0
# 6          77.0              80.0             101.0           16.0
# 7          90.0              56.0              88.0            7.0
#
#    blood oxygen   eye movement  sleeping hours  heart rate  stress level
# 2             88          23.0            24.0        68.0             2
# 3             66          23.0            11.0       165.0             0
# 5             83          25.0            16.0       168.0             3
# 6             99          25.0            24.0       113.0             4
# 7             97          20.0             4.0        38.0             3

# %%
x1 = df.drop(labels='stress level', axis=1)
y1 = df.loc[:,'stress level']

# %%
import imblearn
from imblearn.over_sampling import RandomOverSampler
from collections import Counter

ros =RandomOverSampler(random_state=42)
x,y=ros.fit_resample(x1,y1)
print("OUR DATASET COUNT         : ", Counter(y1))
print("OVER SAMPLING DATA COUNT  : ", Counter(y))
# Out:
# OUR DATASET COUNT         :  Counter({1: 5946, 3: 5872, 4: 5796, 2: 5763, 0: 4353})
# OVER SAMPLING DATA COUNT  :  Counter({2: 5946, 0: 5946, 3: 5946, 4: 5946, 1: 5946})

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42, stratify=y)
print("NUMBER OF TRAIN DATASET    : ", len(x_train))
print("NUMBER OF TEST DATASET      : ", len(x_test))
print("TOTAL NUMBER OF DATASET    : ", len(x_train)+len(x_test))
# Out:
# NUMBER OF TRAIN DATASET    :  23784
# NUMBER OF TEST DATASET      :  5946
# TOTAL NUMBER OF DATASET    :  29730

# %%
print("NUMBER OF TRAIN DATASET    : ", len(y_train))
print("NUMBER OF TEST DATASET      : ", len(y_test))
print("TOTAL NUMBER OF DATASET    : ", len(y_train)+len(y_test))
# Out:
# NUMBER OF TRAIN DATASET    :  23784
# NUMBER OF TEST DATASET      :  5946
# TOTAL NUMBER OF DATASET    :  29730

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
GRB = GradientBoostingClassifier()
GRB.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
predicted = GRB.predict(x_test)

# %%
from sklearn.metrics import classification_report
cr = classification_report(y_test,predicted)
print('THE CLASSIFICATION REPORT OF GradientBoostingClassifier:\n\n',cr)
# Out:
# THE CLASSIFICATION REPORT OF GradientBoostingClassifier:
#
#                precision    recall  f1-score   support
#
#            0       0.32      0.88      0.47      1189
#            1       0.39      0.26      0.32      1189
#            2       0.40      0.25      0.31      1189
#            3       0.44      0.21      0.29      1190
#            4       0.47      0.22      0.30      1189
#
#     accuracy                           0.36      5946
#    macro avg       0.40      0.36      0.33      5946
# weighted avg       0.40      0.36      0.33      5946

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,predicted)
print('THE CONFUSION MATRIX SCORE OF GradientBoostingClassifier:\n\n\n',cm)
# Out:
# THE CONFUSION MATRIX SCORE OF GradientBoostingClassifier:
#
#
#  [[1044   85   45   14    1]
#  [ 539  313  314   12   11]
#  [ 583  282  298    9   17]
#  [ 577   63   35  251  264]
#  [ 548   55   47  281  258]]

# %%
from sklearn.model_selection import cross_val_score
accuracy = cross_val_score(GRB, x, y, scoring='accuracy')
print('THE CROSS VALIDATION TEST RESULT OF ACCURACY :\n\n\n', accuracy*100)
# Out:
# THE CROSS VALIDATION TEST RESULT OF ACCURACY :
#
#
#  [19.74436596 21.12344433 55.60040363 55.71812984 27.14429869]

# %%
from sklearn.metrics import accuracy_score
a = accuracy_score(y_test,predicted)
print("THE ACCURACY SCORE OF GradientBoostingClassifier IS :",accuracy.mean()*100)
# Out:
# THE ACCURACY SCORE OF GradientBoostingClassifier IS : 35.86612848974101

# %%
from sklearn.metrics import hamming_loss
hl = hamming_loss(y_test,predicted)
print("THE HAMMING LOSS OF GradientBoostingClassifier IS :",hl*100)
# Out:
# THE HAMMING LOSS OF GradientBoostingClassifier IS : 63.60578540195089

# %%
def plot_confusion_matrix(cm, title='THE CONFUSION MATRIX SCORE OF GradientBoostingClassifier\n\n', cmap=plt.cm.cool):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

cm1=confusion_matrix(y_test, predicted)
print('THE CONFUSION MATRIX SCORE OF GradientBoostingClassifier:\n\n')
print(cm)
plot_confusion_matrix(cm)
# Out:
# THE CONFUSION MATRIX SCORE OF GradientBoostingClassifier:
#
#
# [[1044   85   45   14    1]
#  [ 539  313  314   12   11]
#  [ 583  282  298    9   17]
#  [ 577   63   35  251  264]
#  [ 548   55   47  281  258]]

# %%
import matplotlib.pyplot as plt
df2 = pd.DataFrame()
df2["y_test"] = y_test
df2["predicted"] = predicted
df2.reset_index(inplace=True)
plt.figure(figsize=(20, 5))
plt.plot(df2["predicted"][:100], marker='x', linestyle='dashed', color='red')
plt.plot(df2["y_test"][:100],  marker='o', linestyle='dashed', color='green')
plt.show()
